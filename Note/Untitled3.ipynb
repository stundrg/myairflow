# %%
import requests
import pandas as pd

# API 요청 정보
url = "https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList"
params = {
    'serviceKey': "ej6vapiMXwvdShcbrvVpBB3QDnLB%2F4PuGsFstLtAnAKc4M8U0W7mN7Xzv9IMLYExY5%2F0RhMdNFnNJ4f7lyoyHg%3D%3D",
    'dataType': 'JSON',
    'dataCd': 'ASOS',
    'dateCd': 'DAY',
    'startDt': '20230401',
    'endDt': '20230401',
    'stnIds': '108',  # 서울
    'numOfRows': '100',
    'pageNo': '1'
}

# 요청 보내기
response = requests.get(url, params=params)

# 응답에서 데이터 꺼내기
data = response.json()['response']['body']['items']['item']

# 표처럼 보기
df = pd.DataFrame(data)
df.head()
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~/code/myairflow/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~/code/myairflow/.venv/lib/python3.12/site-packages/urllib3/connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~/code/myairflow/.venv/lib/python3.12/site-packages/urllib3/connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...
